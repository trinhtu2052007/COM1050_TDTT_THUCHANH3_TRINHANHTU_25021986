# %%
#Bài 1:
n=(input())
so_dao_nguoc=""
for i in n[::-1]:
  so_dao_nguoc=so_dao_nguoc+i
print(so_dao_nguoc)

# %%
#Bài 2:
a=int(input())
b=int(input())
print(f"Trước khi hoán đổi: a = {a}, b = {b}")
a=a^b
b=a^b
a=a^b
print(f"Sau khi hoán đổi: a = {a}, b = {b}")

# %%
#Bài 3:
n=int(input())
if n&(n-1)==0:
  print(True)
else:
  print(False)

# %%
#Bài 4:
import math
m=float(input())
n=float(input())
chia=math.floor(m/n)
print(chia)

# %%
#Bài 5:
import math
m=float(input())
n=float(input())
chia=math.ceil(m/n)
print(chia)

# %%
#Bài 6:
x=float(input())
if x%2==0:
  print("Even")
else:
  print("Odd")

# %%
#Bài 7:
a=int(input())
b=int(input())
if a<0 and b<0:
  print("Yes")
else :
  print("No")

# %%
#Bài 8:
a=input()
b=input()
if len(a)>len(b):
  print("True")
else:
  print("False")

# %%
#Bài 9:
a=float(input())
b=float(input())
c=float(input())
if a+b>c and a+c>b and b+c>a:
  print("Yes")
else:
  print("No")

# %%
#Bài 10:
a=list(map(int,input().split()))
max=a[0]
for i in range (len(a)):
  if a[i]>max:
    max=a[i]
print(max)

# %%
#Bài 11:
a=int(input())
b=int(input())
c=int(input())
if a+b>c and a+c>b and b+c>a:
  if a==b and a==c :
    print("Tam giác đều")
  elif a==b or a==c or b==c:
    print("Tam giác cân")
  else :
    print("Tam giác thường")
else:
  print("Không phải tam giác")

# %%
#Bài 12:
so_kWh=float(input())
if so_kWh<=50:
  tien_dien=so_kWh*1500
elif so_kWh<=100:
  tien_dien=50*1500+(so_kWh-50)*2000
elif so_kWh<=200:
  tien_dien=50*1500+50*2000+(so_kWh-100)*3000
print(tien_dien)

# %%
#Bài 13:
# phương trình ax+b=0
a=float(input())
b=float(input())
if a==0:
  if b==0:
    print("Vô số nghiệm")
  else:
    print("Vô nghiệm")
else:
  print(f"{-b/a:.2f}")

# %%
#Bài 15:
diem_tb=float(input())
if diem_tb>=8:
  print("Giỏi")
elif diem_tb>=6.5:
  print("Khá")
elif diem_tb>=5:
  print("Trung bình")
else:
  print("Yếu")

# %%
#Bài 16:
a=float(input())
phan_nguyen=int(a)
phan_thap_phan=a-phan_nguyen
if phan_thap_phan>0:
  if phan_thap_phan>=0.5:
   so_nguyen=phan_nguyen+1
   len=so_nguyen
   xuong=so_nguyen-1
  else:
    so_nguyen=phan_nguyen
    len=so_nguyen+1
    xuong=so_nguyen
  print(len,xuong,so_nguyen)
elif phan_thap_phan<0:
  if phan_thap_phan<=-0.5:
    so_nguyen=phan_nguyen-1
    len=so_nguyen+1
    xuong=so_nguyen
  else:
    so_nguyen=phan_nguyen
    len=so_nguyen
    xuong=so_nguyen-1
  print(len,xuong,so_nguyen)
else:
  print(phan_nguyen,phan_nguyen,phan_nguyen)
