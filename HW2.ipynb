# %%
# W2A1

print ( " Hello World " )

# %%
# W2A2

ten=input ( " Nhap ten " )
print ( " Xin chao " , ten )

# %%
# W2A3

a =int( input ( " Nhap so nguyen a : " ))
b =int ( input ( " Nhap so nguyen b : " ))
chia_thuc=a/b
chia1=f"{chia_thuc:.2f}"
print ( " a+b =",a+b, " \n a-b =",a-b, " \n a*b =", a*b, "\n phan nguyen a/b =",a//b, "\n phan du a/b = ", a%b ,  "\n a/b = ", chia1)

# %%
# W2A4

diems= input ( "Nhap 6 dau diem theo thu tu")
diems=diems.split ()
diem_tb=(int(diems[0])+int(diems[1])+ int(diems[2])+( int(diems[3])+int(diems[4]))*2 + int(diems[5])*3)/10
print(f"{diem_tb:.1f}")

# %%
# W2A5

so=input ( " Nhap 2 so a b cach nhau boi dau cach : " )
n=so.split ()
m=int(n[0])**int(n[1])
print ( " a**b = ", m )

# %%
# W2A6

a=input( " Nhap mot chu cai thuong  bat ki 'a'...'z' ")
print (" Ma Unicode cua " ,a," la ",ord (a))
print (" Chu cai n hoa tuong ung " ,chr (ord(a)-32))

# %%
# W2A7

A=((13**2)*3)+5
B=13**2*3 +5
print (" ((13**2)*3)+5 =",A,"\n 13**2*3 +5 =",B)

# %%
# W2A8

a=float(input( " Nhap nhiet do theo Celcius"))
b=9/5*a+32
print (" Nhiet do tuong ung theo Fahrenheit",f"{b:.2f}")

# %%
# W2A9

a=float(input(" Nhap so tien goc cua dong ho "))
b=10+a*1.4
print (" So tien Dat phai tra la ",f"{b:.2f}")

# %%
# W2A10

tens=input("Ten 3 ban ").split()
print ("Hi",tens[2],tens[1],"and",tens[0])

# %%
# W2A11

a=input(" Nhap so gio va so phut cach nhau boi dau cach ").split()
h,m=map(float,a)
print (" So giay la" ,h*3600+m*60)

# %%
# W2A12

a=int(input("Nhap do dai canh rubik "))
print (" So luong mieng dan can thiet : ", a*a*6)

# %%
# W2A13

a,b=int(input(" Nhap so nguyen duong a: ")), int(input("Nhap so nguyen duong b:"))
don_vi=(a*b)%10
print(" Hang don vi cua phep a*b ",don_vi)

# %%
# W2A14

a,b=input("a="),input("b=")
b,a=a,b

# %%
# W2A15

a=int(input("Nhap so nguyen duong bat ki :"))
b=6*a*(a-1)+1
print( "so sao thu",a,"la",b)

# %%
# W2A16

print("Spring\nSummer\nAutumn\nWinter")

# %%
# W2A17

print(" "*2+"*")
print(" "+"*"*3)
print("*"*5)

# %%
# W2A18

print("### # #   ### ###")
print(" #  #  #   #   # ")
print(" #  #   #  #   #")
print(" #  #  #   #   #")
print(" #  # #    #   #")

# %%
# W2A19

print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %%
# W2A20

print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")

# %%
# W2A21

for i in range(10):
    print("Hello,world")
